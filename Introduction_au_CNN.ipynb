# %% [markdown]
# <a href="https://colab.research.google.com/github/otmaniamine/deep-learning-projects-Formation-/blob/main/Introduction_au_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Le deep learning

# %% [markdown]
# Aujourd'hui, il existe beaucoup de produits dit "d'Intelligence Artificielle (IA)", ces applications utilisent majoritairement du Machine Learning (ML), qui est un sous-domaine de l'IA, comme vous pouvez le voir ci-dessous. Le machine learning est un champ d'étude qui permet à des programmes de pouvoir résoudre des problèmes à partir de données sans les avoir explicitement programmé. Le deep learning est seulement un des nombreux algorithmes d'apprentissage du machine learning.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/intelligence_artificielle.png?raw=1" width="400">

# %% [markdown]
# Ici, nous allons nous concentrer sur les problèmatiques d'apprentissage supervisé. Nous allons avoir un jeu de données avec des variables explicatives A et des labels B. Le but de notre algorithme, sera d'apprendre à transformer A en B. Comme vous pouvez le voir ci-dessous, la première étape sera l'entraînement, où l'on donnera des données d'entraînement A et B à un algorithme d'apprentissage. Une fois l'entraînement terminé, l'algorithme nous donne un modèle mathématique. Ce modèle pourra prendre des nouvelles données A' afin de pouvoir estimer leurs résultats B'
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/machine_learning.png?raw=1" width="600">

# %% [markdown]
# Le deep learning est un algorithme de machine learning basé sur des neurones artificiels. Ces neurones sont des unités de calculs, ils prenent en entrée des informations, les transforment en une valeur et transmettent cette valeur à d'autres neurones.
#
# <img src ="data/neurone.png" width="600" >
#
# Vous pouvez le voir ci-dessous, si l'on met des neurones artificiels en réseau, nous obtenons un réseau de neurones qui permet de prendre en entrée des données A et de changer la représentation de ces données afin de pouvoir transformer plus facilement A en B.
#
# <img src ="data/réseau_de_neurones.png" width="600" >
#
# Initiallement, cet algorithme était censé représenter artificiellement le comportement du cerveau humain. Aujourd'hui, son fonctionnement est bien loin du fonctionnement du cerveau humain même s'il y a encore du vocabulaire hérité de cette inspiration biologique.

# %% [markdown]
# L'avantage du deep learning réside dans la superposition de couches. Cette superposition permet de changer la représentation des données d'entrées de notre réseau pour mettre en valeur différentes caractéristiques de notre jeux de données. Cette nouvelle représentation est élaboré afin de résoudre notre problème plus efficacement. Comme vous pouvez le voir ci-dessous, ça remplace en partie le processus de feature engineering indispensable aux modèles de machines learning classique.
#
# <img src ="data/ml_vs_dl.png" width="700" >
#
# Cette force, a permi le développement d'algorithme de deep learning très robuste capable de mieux comprendre les données non structurés tels que du texte, du son et des images.

# %% [markdown]
# ## Les architectures de Convolutional Neural Network (CNN)
#
# Comme nous l'avons vue précédemment, le principal avantage des réseaux de neurones par rapport aux algorithmes de machine learning traditionnels est que les algorithmes de deep learning apprennent des représentations par eux-mêmes, alors que dans le machine learning traditionnel, on définie des variables à la main sensés être une meilleure représentation des données. C'est vrai pour les réseaux de neurones de type "fully connected" qui ne sont constitués que de couches entièrement connectées. Mais il est très difficile de les entraîner pour des entrées de haute dimension comme les images.
#
# Lorsque vous utilisez une architecture de CNN, vous utilisez deux types de fonctionnalités artisanales : les convolutional layers (les filtres de convolution) et les poolign layers (les filtres de regroupement).
#
# Le concepteur du CNN pour la classification des images a examiné les données d'entrée (c'est ce que font les ingénieurs en machine learning traditionnels pour inventer des fonctionnalités) et a décidé que des patchs de pixels proches les uns des autres contiennent des informations qui pourraient aider à la classification, et en même temps réduire le nombre de paramètres. Vous pouvez voir l'application d'un patch sur une image ci-dessous.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/application_de_patchs.gif?raw=1" width="500" >
#
# En effet, l'application de patchs sur une image permet de transformer l'image et de faire ressortir certaines de ces caractéristiques comme vous pouvez le voir ci-dessous.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/filters.png?raw=1" width="500" >

# %% [markdown]
# Le but du CNN est de transformer notre image de départ en vecteur qui serait la représentation vectorielle des caractéristiques de notre image.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/conv_nn.png?raw=1" width="600" >
#
# Une fois que nous avons extrait les caractéristiques de notre image sous forme de vecteur, nous pouvons utiliser cette représentation afin de résoudre un problème lié à notre image. Sur l'illustration ci-dessous, vous pouvez bien voir les deux différentes parties qui consistuent notre réseau.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/CNN.png?raw=1" width="800" >

# %% [markdown]
# ## Exemple CNN

# %% [markdown]
# Ne vous inquiétez pas, vous n'allez pas avoir besoin de connaître toutes les mathématiques qui se cachent derrière les réseaux convolutionel pour pouvoir les utiliser.
# Grâce à Tensorflow et sa sur-couche Keras, vous pouvez construire un modèle en quelques cliques.
#
# ### Sélection du matériel
#
# Avant de commencer nous allons sélectionné le matériel adapté à nos calculs. Le deep learning à besoin de cartes graphiques (GPU) afin de réduire le temps de calculs.
#
# Appuyer sur "Exécution" -> "Modifier le type d'exécution"
#
# Dans "Accélérateur matériel" sélectionnez GPU puis appuyer sur enregistrer.
#
# ### Importation des packages
#
# On va commencer par importer les packages nécessaires à l'élaboration de notre modèle.

# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
import tensorflow as tf
from tensorflow.python.framework import ops

import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

# %% [markdown]
# ### Importations des données
#
# Maintenant que nos outils sont chargés, nous allons charger nos données.
#
# Cliquez sur le lien ci-dessous :
#
# https://drive.google.com/open?id=1Wg3FnIydOdu6twEpu3iB8inZghsIIV1d
#
# Cliquer droit sur le dossier data et appuyer sur ajouter à mon drive.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/images/data_google_drive.png?raw=1" width="800" >

# %% [markdown]
# Exécutez la cellule ci-dessous et appuyer sur le lien proposé.
#
# Suivez les instructions et copier le code ci-dessous.

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Les données sont maintenant dans votre environnement collab.

# %%
train_dataset = h5py.File('/content/train_signs.h5', "r")
train_set_x_orig = np.array(train_dataset["train_set_x"][:])
train_set_y_orig = np.array(train_dataset["train_set_y"][:])

test_dataset = h5py.File('/content/test_signs.h5', "r")
test_set_x_orig = np.array(test_dataset["test_set_x"][:])
test_set_y_orig = np.array(test_dataset["test_set_y"][:])

classes = np.array(test_dataset["list_classes"][:])

train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))

input_shape = train_set_x_orig[0].shape

# %% [markdown]
# Dans cet exemple, nous allons créer un modèle de deep learning capable de reconnaître quel chiffre fait la main sur une photo. Comme vous pouvez le voir ci-dessous, nous avons 5 classes.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/signes.png?raw=1" width="800" >

# %% [markdown]
# Vous pouvez directement voir les exemples depuis le jeu de données.

# %%
# Example of a picture
index = 5
plt.imshow(train_set_x_orig[index])
print ("y = " + str(np.squeeze(train_set_y_orig[:, index])))
# Out:
# y = 4

# %% [markdown]
# Vous pouvez voir ci-dessous que nos images sont en trois dimensions 64 x 64 x 3.
#
# La première dimension de 64 correspond à la hauteur en pixel de la photo, ici 64 pixels.
#
# La deuxième dimension de 64 correspond à la largeur en pixel de la photo, ici 64 pixels.
#
# La troisième dimension correspond aux intensités de rouge, de vert et de bleu nécessaires pour former la couleur du pixel.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/RGB-color-model.jpg?raw=1" width="300" >

# %%
print(train_set_x_orig[0].shape)
# Out:
# (64, 64, 3)

# %% [markdown]
# Pour créer des images en informatique, il n'y a pas une intensité par couleur, ce serait trop complexe à organiser. Pour remédier à cela, nous avons pris trois couleurs (rouge, vert et bleu) et chaque couleur sera une combinaison d'intensité de ces trois couleurs. Le schéma ci-dessous va sûrement vous aider à comprendre le problème.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/image_en_rgb.png?raw=1" width="600" >

# %% [markdown]
# ### Normalisation
#
# Pour des raisons d'optimisation, nous voulons que les données d'entrées de notre modèle soient normalisées.
#
# La bonne nouvelle, c'est que les intensités d'une image sont toujours comprises entre 0 et 255. Nous allons donc utiliser la min-max normalisation afin de réduire la valeur des intensités de nos images.

# %%
print('Valeur maximum de nos images : ',np.min(train_set_x_orig))
print('Valeur minimum de nos images : ', np.max(train_set_x_orig))

X_train = train_set_x_orig.astype('float32')/255
X_test = test_set_x_orig.astype('float32')/255

print('Valeur maximum de nos images normalisées : ',np.min(X_train))
print('Valeur minimum de nos images normalisées : ',np.max(X_train))
# Out:
# Valeur maximum de nos images :  4
# Valeur minimum de nos images :  244
# Valeur maximum de nos images normalisées :  0.015686275
# Valeur minimum de nos images normalisées :  0.95686275

# %% [markdown]
# Dans nos vecteurs "train_set_y_orig" et "test_set_y_orig" nous avons le chiffre correspondant à l'image de la main.
#
# Nous allons transformer nos valeurs en hot vecteur, c'est-à-dire au lieu d'avoir la valeur 5 on aura un vecteur avec un 1 à la 6ème case.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/hot_vecteur.png?raw=1" width="800" >

# %%
print(train_set_y_orig.shape)
print(test_set_y_orig.shape)
# Out:
# (1, 1080)
# (1, 120)

# %%
Y_train = np.eye(6)[train_set_y_orig.reshape(-1)]
Y_test = np.eye(6)[test_set_y_orig.reshape(-1)]
print(Y_train[150, :])
print((train_set_y_orig[:, 150]))
# Out:
# [0. 0. 0. 1. 0. 0.]
# [3]

# %% [markdown]
# ### Construction de notre modèle

# %% [markdown]
# Ici nous allons créer un modèle basique de CNN.

# %%
model = Sequential()

# %% [markdown]
# Nous allons commencer notre modèle par une couche de convolution. Comme vous pouvez voir ci-dessous, c'est simplement l'application d'un filtre sur notre image pour extraire des caractéristiques.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/convolution_anim.gif?raw=1" width="800" >

# %%
model.add(Conv2D(32,
                 kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(64,64,3)))
model.add(Conv2D(32,
                 kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(64,64,3)))

# %% [markdown]
# Nous allons maintenant ajouter une couche de max-pooling. Comme vous pouvez voir ci-dessous, c'est simplement la sélection de l'intensité la plus grande parmi une sélection de pixels.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/pooling_anim.gif?raw=1" width="800" >

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %% [markdown]
# Maintenant que nous avons extrait des informations de notre image, nous allons transformer ces représentations en vecteur.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/flatten.gif?raw=1" width="500" >

# %%
model.add(Flatten())

# %% [markdown]
# Pour finir, nous allons utiliser des couches entièrement connectées pour prédire l'appartenance de nos observations à nos classes.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/fully_connected.png?raw=1" width="500" >

# %%
model.add(Dense(6, activation='softmax'))

# %% [markdown]
# Notre modèle est assemblé, nous pouvons maintenant le visualiser.

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 62, 62, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 60, 60, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 30, 30, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 28800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │       172,806 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 182,950 (714.65 KB)
#  Trainable params: 182,950 (714.65 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Voici une représentation plus visuelle du modèle.
#
# <img src="https://github.com/MorganGautherot/Tuto_MRI_ML/blob/master/tp_1/data/baseline.png?raw=1" width="800" >

# %% [markdown]
# Nous voilà à la dernière étape, l'entraînement de notre modèle.

# %%
model.compile(loss="categorical_crossentropy", optimizer=SGD(learning_rate=0.01), metrics=["accuracy"])
model.fit(X_train, Y_train,
          epochs = 100,
          validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.1852 - loss: 1.8050 - val_accuracy: 0.3333 - val_loss: 1.7764
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2444 - loss: 1.7464 - val_accuracy: 0.3917 - val_loss: 1.6980
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3407 - loss: 1.6644 - val_accuracy: 0.2667 - val_loss: 1.5934
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3648 - loss: 1.5690 - val_accuracy: 0.5333 - val_loss: 1.4629
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4778 - loss: 1.4185 - val_accuracy: 0.4750 - val_loss: 1.4225
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5185 - loss: 1.3234 - val_accuracy: 0.5167 - val_loss: 1.2328
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5611 - loss: 1.1862 - val_accuracy: 0.4917 - val_loss: 1.1310
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6019 - loss: 1.0710 - val_accuracy: 0.4667 - val_loss: 1.1994
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6019 - loss: 1.0354 - val_accuracy: 0.4333 - val_loss: 1.3052
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6481 - loss: 0.9744 - val_accuracy: 0.6417 - val_loss: 0.9365
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6750 - loss: 0.9239 - val_accuracy: 0.5833 - val_loss: 1.1204
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7102 - loss: 0.8498 - val_accuracy: 0.5833 - val_loss: 1.0477
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7509 - loss: 0.7687 - val_accuracy: 0.5833 - val_loss: 1.0438
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5306 - loss: 1.5684 - val_accuracy: 0.4500 - val_loss: 1.2650
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6741 - loss: 0.9500 - val_accuracy: 0.5250 - val_loss: 1.2266
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7148 - loss: 0.8182 - val_accuracy: 0.7417 - val_loss: 0.8220
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7361 - loss: 0.7220 - val_accuracy: 0.7583 - val_loss: 0.7560
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7898 - loss: 0.6328 - val_accuracy: 0.7583 - val_loss: 0.7875
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8093 - loss: 0.5630 - val_accuracy: 0.6417 - val_loss: 0.9066
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7648 - loss: 0.7030 - val_accuracy: 0.8000 - val_loss: 0.6325
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8556 - loss: 0.4586 - val_accuracy: 0.8167 - val_loss: 0.5845
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8157 - loss: 0.5405 - val_accuracy: 0.7833 - val_loss: 0.6173
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8759 - loss: 0.3995 - val_accuracy: 0.7000 - val_loss: 0.8922
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8676 - loss: 0.4278 - val_accuracy: 0.8500 - val_loss: 0.5357
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9019 - loss: 0.3335 - val_accuracy: 0.8250 - val_loss: 0.5571
# Epoch 26/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9009 - loss: 0.3244 - val_accuracy: 0.7750 - val_loss: 0.6433
# Epoch 27/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9056 - loss: 0.3035 - val_accuracy: 0.7833 - val_loss: 0.6505
# Epoch 28/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9120 - loss: 0.2955 - val_accuracy: 0.8667 - val_loss: 0.4634
# Epoch 29/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9269 - loss: 0.2462 - val_accuracy: 0.8167 - val_loss: 0.5270
# Epoch 30/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9000 - loss: 0.2944 - val_accuracy: 0.8250 - val_loss: 0.4829
# Epoch 31/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9065 - loss: 0.2833 - val_accuracy: 0.8583 - val_loss: 0.4582
# Epoch 32/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9287 - loss: 0.2119 - val_accuracy: 0.8167 - val_loss: 0.5361
# Epoch 33/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9454 - loss: 0.1973 - val_accuracy: 0.8083 - val_loss: 0.5099
# Epoch 34/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9157 - loss: 0.2631 - val_accuracy: 0.8917 - val_loss: 0.4051
# Epoch 35/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9463 - loss: 0.1896 - val_accuracy: 0.8917 - val_loss: 0.4050
# Epoch 36/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9398 - loss: 0.1833 - val_accuracy: 0.7833 - val_loss: 0.6307
# Epoch 37/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9565 - loss: 0.1603 - val_accuracy: 0.8667 - val_loss: 0.4378
# Epoch 38/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7731 - loss: 1.5212 - val_accuracy: 0.6167 - val_loss: 1.2144
# Epoch 39/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7056 - loss: 0.8360 - val_accuracy: 0.5917 - val_loss: 1.0884
# Epoch 40/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7759 - loss: 0.6691 - val_accuracy: 0.7667 - val_loss: 0.6471
# Epoch 41/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8287 - loss: 0.5635 - val_accuracy: 0.6083 - val_loss: 1.3655
# Epoch 42/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8093 - loss: 0.5993 - val_accuracy: 0.8417 - val_loss: 0.5713
# Epoch 43/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8796 - loss: 0.3842 - val_accuracy: 0.7667 - val_loss: 0.6802
# Epoch 44/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9009 - loss: 0.3340 - val_accuracy: 0.8333 - val_loss: 0.5186
# Epoch 45/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8954 - loss: 0.3490 - val_accuracy: 0.7500 - val_loss: 0.6549
# Epoch 46/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8741 - loss: 0.4264 - val_accuracy: 0.4333 - val_loss: 1.9878
# Epoch 47/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8926 - loss: 0.3569 - val_accuracy: 0.8417 - val_loss: 0.4934
# Epoch 48/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9343 - loss: 0.2415 - val_accuracy: 0.8417 - val_loss: 0.5144
# Epoch 49/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9500 - loss: 0.2054 - val_accuracy: 0.8500 - val_loss: 0.4736
# Epoch 50/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9259 - loss: 0.2629 - val_accuracy: 0.8583 - val_loss: 0.4332
# Epoch 51/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9528 - loss: 0.1913 - val_accuracy: 0.8167 - val_loss: 0.5419
# Epoch 52/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9407 - loss: 0.2117 - val_accuracy: 0.8333 - val_loss: 0.4862
# Epoch 53/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9639 - loss: 0.1418 - val_accuracy: 0.8583 - val_loss: 0.4352
# Epoch 54/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9546 - loss: 0.1621 - val_accuracy: 0.7167 - val_loss: 0.7548
# Epoch 55/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9370 - loss: 0.2086 - val_accuracy: 0.8833 - val_loss: 0.4336
# Epoch 56/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9713 - loss: 0.1229 - val_accuracy: 0.8667 - val_loss: 0.4203
# Epoch 57/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9537 - loss: 0.1768 - val_accuracy: 0.8583 - val_loss: 0.3828
# Epoch 58/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9796 - loss: 0.1027 - val_accuracy: 0.8500 - val_loss: 0.4472
# Epoch 59/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9519 - loss: 0.1544 - val_accuracy: 0.8917 - val_loss: 0.3770
# Epoch 60/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9806 - loss: 0.0929 - val_accuracy: 0.8833 - val_loss: 0.4634
# Epoch 61/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9787 - loss: 0.0886 - val_accuracy: 0.7917 - val_loss: 0.5522
# Epoch 62/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9685 - loss: 0.1033 - val_accuracy: 0.8667 - val_loss: 0.4123
# Epoch 63/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9815 - loss: 0.0850 - val_accuracy: 0.8417 - val_loss: 0.5347
# Epoch 64/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7343 - loss: 1.3560 - val_accuracy: 0.4000 - val_loss: 1.6504
# Epoch 65/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5176 - loss: 1.5175 - val_accuracy: 0.4250 - val_loss: 1.4654
# Epoch 66/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5917 - loss: 1.3010 - val_accuracy: 0.5417 - val_loss: 1.2376
# Epoch 67/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6731 - loss: 1.0445 - val_accuracy: 0.6833 - val_loss: 0.9659
# Epoch 68/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7537 - loss: 0.7518 - val_accuracy: 0.7333 - val_loss: 0.8310
# Epoch 69/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7991 - loss: 0.6488 - val_accuracy: 0.7250 - val_loss: 0.7672
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8454 - loss: 0.4993 - val_accuracy: 0.8417 - val_loss: 0.5635
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8880 - loss: 0.3685 - val_accuracy: 0.7167 - val_loss: 0.6206
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9194 - loss: 0.3093 - val_accuracy: 0.8667 - val_loss: 0.4903
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9472 - loss: 0.2495 - val_accuracy: 0.8417 - val_loss: 0.5100
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9454 - loss: 0.2326 - val_accuracy: 0.9000 - val_loss: 0.4681
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9528 - loss: 0.1983 - val_accuracy: 0.8333 - val_loss: 0.4507
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9593 - loss: 0.1861 - val_accuracy: 0.9000 - val_loss: 0.3932
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9556 - loss: 0.1827 - val_accuracy: 0.9000 - val_loss: 0.4078
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9713 - loss: 0.1317 - val_accuracy: 0.9083 - val_loss: 0.3933
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9806 - loss: 0.1190 - val_accuracy: 0.8667 - val_loss: 0.4046
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9731 - loss: 0.1239 - val_accuracy: 0.8417 - val_loss: 0.3949
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9833 - loss: 0.0917 - val_accuracy: 0.8833 - val_loss: 0.3765
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9861 - loss: 0.0848 - val_accuracy: 0.8750 - val_loss: 0.3844
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9880 - loss: 0.0810 - val_accuracy: 0.9000 - val_loss: 0.3417
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9907 - loss: 0.0650 - val_accuracy: 0.8500 - val_loss: 0.3874
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9907 - loss: 0.0641 - val_accuracy: 0.8833 - val_loss: 0.3518
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9944 - loss: 0.0570 - val_accuracy: 0.8750 - val_loss: 0.3580
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9954 - loss: 0.0509 - val_accuracy: 0.8917 - val_loss: 0.3359
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9944 - loss: 0.0457 - val_accuracy: 0.8833 - val_loss: 0.3364
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9954 - loss: 0.0401 - val_accuracy: 0.8833 - val_loss: 0.3491
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9981 - loss: 0.0368 - val_accuracy: 0.9000 - val_loss: 0.3861
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9972 - loss: 0.0379 - val_accuracy: 0.9083 - val_loss: 0.3478
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9991 - loss: 0.0326 - val_accuracy: 0.8917 - val_loss: 0.3636
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9981 - loss: 0.0308 - val_accuracy: 0.9000 - val_loss: 0.3477
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9991 - loss: 0.0276 - val_accuracy: 0.8917 - val_loss: 0.3979
# Epoch 95/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9991 - loss: 0.0271 - val_accuracy: 0.9000 - val_loss: 0.3665
# Epoch 96/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9991 - loss: 0.0248 - val_accuracy: 0.9083 - val_loss: 0.3728
# Epoch 97/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0225 - val_accuracy: 0.9167 - val_loss: 0.3943
# Epoch 98/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0231 - val_accuracy: 0.9000 - val_loss: 0.3647
# Epoch 99/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0198 - val_accuracy: 0.8917 - val_loss: 0.3942
# Epoch 100/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0202 - val_accuracy: 0.8833 - val_loss: 0.3775

# %% [markdown]
# Pour finir ce notebook, nous allons sauvegarder les paramètres de notre modèle si nous voulons l'utiliser à nouveau plus tard.

# %%
model.save_weights("model.weights.h5")
